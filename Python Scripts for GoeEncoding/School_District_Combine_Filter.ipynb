# %%
import pandas as pd
import numpy as np

# %%
ele = pd.read_csv('/Users/miana/Downloads/Neo4j_clean_data/elementary_school_district_wkt.csv')

# %%
ele = ele.iloc[:,1:]

# %%
ele = ele.rename(columns = {'ELSDLEA' : 'SDLEA'})

# %%
ele['school_district_type'] = 'Elementary'

# %%
ele.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                  NAME  LSAD  \
# 0       27    388  2700388    Round Lake-Brewster Public Schools     0
# 1       27   7110  2707110  Browns Valley Public School District     0
# 2       27  15540  2715540        Ivanhoe Public School District     0
# 3       27  17460  2717460    Lake Benton Public School District     0
# 4       27  18390  2718390           Lynd Public School District     0
# 5       27  21210  2721210         Milroy Public School District     0
# 6       27  33720  2733720      Nett Lake Public School District     0
# 7       27  28960  2728960     Pine Point Public School District     0
#
#   LOGRADE  HIGRADE  MTFCC  SDTYP FUNCSTAT      ALAND    AWATER   INTPTLAT  \
# 0      PK        8  G5400    NaN        E  355350345   6452268  43.634020
# 1      PK        8  G5400    NaN        E  120256291  18198228  45.651305
# 2      PK        6  G5400    NaN        E  374419867   9590646  44.467605
# ...

# %%
sec = pd.read_csv('/Users/miana/Downloads/Neo4j_clean_data/secondary_school_district_wkt.csv')

# %%
sec =sec.iloc[:,1:]

# %%
sec = sec.rename(columns = {'SCSDLEA' : 'SDLEA'})

# %%
sec['school_district_type'] = 'Secondary'

# %%
sec.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                               NAME  \
# 0       27  27001  2727001  Park Rapids Public School District in Pine Poi...
# 1       27  27002  2727002  Clinton-Graceville-Beardsley-Wheaton-Sisseton/...
# 2       27  27003  2727003  Minneota-Ivanhoe Public School Districts in Iv...
# 3       27  27004  2727004  Marshall-Minneota-RTR Public Schools in Lynd (...
# 4       27  27005  2727005     Marshall-Tracy Public Schools in Milroy (9-12)
# 5       27  27006  2727006  Heron Lake-Okabena-Fulda-Worthington in Round ...
# 6       27  27007  2727007            St. Louis-Northland in Nett Lake (7-12)
# 7       27  99001  2799001  Elkton School District 05-3 in Lake Benton (7-12)
#
#    LSAD  LOGRADE  HIGRADE  MTFCC SDTYP FUNCSTAT      ALAND    AWATER  \
# 0     0        9       12  G5410     A        F   10707431   2071546
# 1     0        9       12  G5410     A        F  120256291  18198228
# ...

# %%
uni = pd.read_csv('/Users/miana/Downloads/Neo4j_clean_data/unified_school_district_wkt.csv')

# %%
uni =uni.iloc[:,1:]

# %%
uni = uni.rename(columns = {'UNSDLEA' : 'SDLEA'})

# %%
uni['school_district_type'] = 'Unified'

# %%
uni.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                NAME  LSAD LOGRADE  \
# 0       27   9440  2709440       Rocori Public School District     0      PK
# 1       27   8910  2708910     Chisholm Public School District     0      PK
# 2       27  11520  2711520          Ely Public School District     0      PK
# 3       27  12210  2712210    Floodwood Public School District     0      PK
# 4       27   9540  2709540      Comfrey Public School District     0      KG
# 5       27  23010  2723010        Mountain Lake Public Schools     0      PK
# 6       27  16980  2716980  Kasson-Mantorville School District     0      PK
# 7       27    287  2700287           Plainview-Elgin-Millville     0      PK
# 8       27  13590  2713590     Hayfield Public School District     0      PK
# 9       27    130  2700130      Blue Earth Area Public Schools     0      PK
#
#    HIGRADE  MTFCC  SDTYP FUNCSTAT       ALAND    AWATER   INTPTLAT   INTPTLON  \
# ...

# %%
frames = [ele, sec, uni]

# %%
result = pd.concat(frames, sort = False)

# %%
len(result)
# Out:
# 340

# %%
result.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                               NAME  \
# 0       27    388  2700388                 Round Lake-Brewster Public Schools
# 1       27   7110  2707110               Browns Valley Public School District
# 2       27  15540  2715540                     Ivanhoe Public School District
# 3       27  17460  2717460                 Lake Benton Public School District
# 4       27  18390  2718390                        Lynd Public School District
# 5       27  21210  2721210                      Milroy Public School District
# 6       27  33720  2733720                   Nett Lake Public School District
# 7       27  28960  2728960                  Pine Point Public School District
# 0       27  27001  2727001  Park Rapids Public School District in Pine Poi...
# 1       27  27002  2727002  Clinton-Graceville-Beardsley-Wheaton-Sisseton/...
#
#    LSAD LOGRADE  HIGRADE  MTFCC SDTYP FUNCSTAT      ALAND    AWATER  \
# ...

# %%
# filter school district

# %%
HC_school_district = pd.read_csv('/Users/miana/Downloads/Neo4j_clean_data/district_tract.csv')

# %%
HC_school_district.head(10)
# Out:
#      LEAID                             NAME_LEA19        TRACT
# 0  2703180  Anoka-Hennepin Public School District  27053020200
# 1  2703180  Anoka-Hennepin Public School District  27053020301
# 2  2703180  Anoka-Hennepin Public School District  27053026707
# 3  2703180  Anoka-Hennepin Public School District  27053026811
# 4  2703180  Anoka-Hennepin Public School District  27053026812
# 5  2703180  Anoka-Hennepin Public School District  27053026814
# 6  2703180  Anoka-Hennepin Public School District  27053026815
# 7  2703180  Anoka-Hennepin Public School District  27053026820
# 8  2703180  Anoka-Hennepin Public School District  27053026822
# 9  2703180  Anoka-Hennepin Public School District  27053026823

# %%
HC_district_wkt = result[result['GEOID'].isin(HC_school_district['LEAID'].tolist())]
HC_district_wkt.head(10)
# Out:
#      STATEFP  SDLEA    GEOID                                   NAME  LSAD  \
# 125       27   3180  2703180  Anoka-Hennepin Public School District     0
# 126       27  10170  2710170          Delano Public School District     0
# 127       27  11670  2711670      Minnetonka Public School District     0
# 128       27  14220  2714220    Eden Prairie Public School District     0
# 129       27  22920  2722920        Westonka Public School District     0
# 130       27  25200  2725200           Osseo Public School District     0
# 131       27  42160  2742160         Wayzata Public School District     0
# 205       27   5790  2705790     Bloomington Public School District     0
# 206       27  32070  2732070        Rockford Public School District     0
# 271       27   6240  2706240        Brooklyn Center School District     0
#
#     LOGRADE  HIGRADE  MTFCC SDTYP FUNCSTAT      ALAND    AWATER   INTPTLAT  \
# 125      PK       12  G5420   NaN        E  427660606  17984633  45.217322
# ...

# %%
len(HC_district_wkt['GEOID'].unique())
# Out:
# 23

# %%
HC_district_wkt.to_csv(r'/Users/miana/Downloads/Neo4j_clean_data/HC_district_wkt.csv', index = False, header=True)

# %%
len(HC_district_wkt)
# Out:
# 23

# %%
pd.read_csv('/Users/miana/Downloads/un_district_wkt.csv')
# Out:
#     Unnamed: 0  STATEFP  UNSDLEA    GEOID                             NAME  \
# 0            0       27     3180  2703180            Anoka-Hennepin Public
# 1            1       27    10170  2710170                    Delano Public
# 2            2       27    11670  2711670                Minnetonka Public
# 3            3       27    14220  2714220              Eden Prairie Public
# 4            4       27    22920  2722920                  Westonka Public
# 5            5       27    25200  2725200                     Osseo Public
# 6            6       27    42160  2742160                   Wayzata Public
# 7            7       27     5790  2705790               Bloomington Public
# 8            8       27    32070  2732070                  Rockford Public
# 9            9       27     6240  2706240                  Brooklyn Center
# 10          10       27     7200  2707200  Buffalo-Hanover-Montrose Public
# ...

# %%
import pandas as pd
import numpy as np
import geopandas

# %%
district = pd.read_csv('/Users/miana/Downloads/Neo4j_clean_data/HC_district_wkt.csv')

# %%
district.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                   NAME  LSAD  \
# 0       27   3180  2703180  Anoka-Hennepin Public School District     0
# 1       27  10170  2710170          Delano Public School District     0
# 2       27  11670  2711670      Minnetonka Public School District     0
# 3       27  14220  2714220    Eden Prairie Public School District     0
# 4       27  22920  2722920        Westonka Public School District     0
# 5       27  25200  2725200           Osseo Public School District     0
# 6       27  42160  2742160         Wayzata Public School District     0
# 7       27   5790  2705790     Bloomington Public School District     0
# 8       27  32070  2732070        Rockford Public School District     0
# 9       27   6240  2706240        Brooklyn Center School District     0
#
#   LOGRADE  HIGRADE  MTFCC  SDTYP FUNCSTAT      ALAND    AWATER   INTPTLAT  \
# 0      PK       12  G5420    NaN        E  427660606  17984633  45.217322
# ...

# %%
gdf = geopandas.GeoDataFrame(
    district, geometry=geopandas.points_from_xy(district.INTPTLAT, district.INTPTLON))

# %%
gdf.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                   NAME  LSAD  \
# 0       27   3180  2703180  Anoka-Hennepin Public School District     0
# 1       27  10170  2710170          Delano Public School District     0
# 2       27  11670  2711670      Minnetonka Public School District     0
# 3       27  14220  2714220    Eden Prairie Public School District     0
# 4       27  22920  2722920        Westonka Public School District     0
# 5       27  25200  2725200           Osseo Public School District     0
# 6       27  42160  2742160         Wayzata Public School District     0
# 7       27   5790  2705790     Bloomington Public School District     0
# 8       27  32070  2732070        Rockford Public School District     0
# 9       27   6240  2706240        Brooklyn Center School District     0
#
#   LOGRADE  HIGRADE  MTFCC  SDTYP FUNCSTAT      ALAND    AWATER   INTPTLAT  \
# 0      PK       12  G5420    NaN        E  427660606  17984633  45.217322
# ...

# %%
district = district.rename(columns={"geometry": "PointWKT"})

# %%
district.head(10)
# Out:
#    STATEFP  SDLEA    GEOID                                   NAME  LSAD  \
# 0       27   3180  2703180  Anoka-Hennepin Public School District     0
# 1       27  10170  2710170          Delano Public School District     0
# 2       27  11670  2711670      Minnetonka Public School District     0
# 3       27  14220  2714220    Eden Prairie Public School District     0
# 4       27  22920  2722920        Westonka Public School District     0
# 5       27  25200  2725200           Osseo Public School District     0
# 6       27  42160  2742160         Wayzata Public School District     0
# 7       27   5790  2705790     Bloomington Public School District     0
# 8       27  32070  2732070        Rockford Public School District     0
# 9       27   6240  2706240        Brooklyn Center School District     0
#
#   LOGRADE  HIGRADE  MTFCC  SDTYP FUNCSTAT      ALAND    AWATER   INTPTLAT  \
# 0      PK       12  G5420    NaN        E  427660606  17984633  45.217322
# ...

# %%
district.to_csv(r'/Users/miana/Downloads/Neo4j_clean_data/HC_district_wkt.csv', index = False, header=True)
